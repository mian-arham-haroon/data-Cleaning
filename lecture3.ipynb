# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
bs=pd.read_csv('titanic.csv')
(bs.isnull().sum()/bs.shape[0])*100     #
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
bs.shape[1]
# bs.shape[0]
s=bs.isnull().sum().sum()     #total number of missing values in the dataframe
s/bs.s*100
# Out:
# np.float64(97.19416386083053)

# %%
bs.size     
bs.shape[0]*bs.shape[1] 
round(bs.isnull().sum().sum()/bs.size*100,2)
bs.notnull().sum().sum() 
bs.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
sns.heatmap(bs.isnull(),yticklabels=False,cbar=True,cmap='viridis')
# Out:
# <Axes: >
